# %%
import pandas as pd
import altair as alt
alt.data_transformers.enable('data_server')
# Out:
# DataTransformerRegistry.enable('data_server')

# %%
df = pd.read_csv("../data/raw/olympics_data.csv", index_col = 0)

# %%
filter_df = df[df['medal'].notna()]
filter_df
# Out:
#             id                                 name sex   age  height  weight  \
# 3            4                 Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 37          15                 Arvo Ossian Aaltonen   M  30.0     NaN     NaN
# 38          15                 Arvo Ossian Aaltonen   M  30.0     NaN     NaN
# 40          16             Juhamatti Tapio Aaltonen   M  28.0   184.0    85.0
# 41          17              Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# ...        ...                                  ...  ..   ...     ...     ...
# 271078  135553  Galina Ivanovna Zybina (-Fyodorova)   F  25.0   168.0    80.0
# 271080  135553  Galina Ivanovna Zybina (-Fyodorova)   F  33.0   168.0    80.0
# 271082  135554                         Bogusaw Zych   M  28.0   182.0    82.0
# 271102  135563            Olesya Nikolayevna Zykina   F  19.0   171.0    64.0
# 271103  135563            Olesya Nikolayevna Zykina   F  23.0   171.0    64.0
#
# ...

# %%
age_hist_df = filter_df
# age_hist_df["Bronze"] = age_hist_df.medal == "Bronze"
# age_hist_df["Silver"] = age_hist_df.medal == "Silver"
# age_hist_df["Gold"] = age_hist_df.medal == "Gold"

# age_hist_df = filter_df.groupby(by="age").agg(
#     bronze_medals=pd.NamedAgg(column="medal", aggfunc='count'))

# age_hist_df = filter_df.groupby(by="age").agg(
#     bronze_medals=pd.NamedAgg(column="medal", aggfunc=lambda x: sum(x=="Bronze")),
#     silver_medals=pd.NamedAgg(column="medal", aggfunc=lambda x: sum(x=="Silver")),
#     gold_medals=pd.NamedAgg(column="medal", aggfunc=lambda x: sum(x=="Gold")))

# age_hist_df

# %%
order = ["Gold", "Silver", "Bronze"]
# plot_df = filter_df

plot_df = filter_df[filter_df['age'].between(10, 50)]
plot_df["order"] = filter_df["medal"].replace({ 'Bronze' : 1, 'Silver' : 2, 'Gold' : 3 })

alt.Chart(plot_df).mark_area(
    interpolate='step'
).encode(
    alt.X('age:Q', bin=alt.Bin(maxbins=100)),
    alt.Y('count()'),
    alt.Color('medal:N',
              sort=["Gold", "Silver", "Bronze"],
              scale=alt.Scale(
                        domain=['Bronze', 'Silver', 'Gold'],
                        range=['#CD7F32', '#C0C0C0', '#FFD700'])),
    order=alt.Order('order', sort='ascending')
).properties(
    title='Overlapping Histograms from Tidy/Long Data'
)
# Out:
# C:\Users\andy8\AppData\Local\Temp\ipykernel_18936\3949723028.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   plot_df["order"] = filter_df["medal"].replace({ 'Bronze' : 1, 'Silver' : 2, 'Gold' : 3 })
# alt.Chart(...)
